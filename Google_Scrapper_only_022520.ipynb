# %% [markdown]
# # 1. Load data
# Load cvs file and retrieve bar and restaurants' names and addresses

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd

pd.options.display.max_rows = 30

# %%
bars=pd.read_csv('Mixed_Beverage_Gross_Receipts.csv')

# %%
bars.columns
# Out:
# Index(['Taxpayer Number', 'Taxpayer Name', 'Taxpayer Address', 'Taxpayer City',
#        'Taxpayer State', 'Taxpayer Zip', 'Taxpayer County', 'Location Number',
#        'Location Name', 'Location Address', 'Location City', 'Location State',
#        'Location Zip', 'Location County', 'Inside/Outside City Limits',
#        'TABC Permit Number', 'Responsibility Begin Date',
#        'Responsibility End Date', 'Obligation End Date', 'Liquor Receipts',
#        'Wine Receipts', 'Beer Receipts', 'Cover Charge Receipts',
#        'Total Receipts'],
#       dtype='object')

# %%
bars2=bars[['Location Name','Location Address','Location City','Location State','Location Zip','Location County']]

# %%
bars2.tail(10)
# bars2['Location Name'].astype(str) + bars2['Location Address']
# Out:
#                        Location Name  \
# 2448545               RED MESA GRILL
# 2448546                    CLUB RIVE
# 2448547   LUCKY STRIKE HOUSTON L L C
# 2448548                  VELVET TACO
# 2448549  WYNDHAM GARDEN DALLAS NORTH
# 2448550           LEAPIN' LIZARD PUB
# 2448551                LOS GENERALES
# 2448552              GRUB BURGER BAR
# 2448553          LAYNE-KITE POST 181
# 2448554           STUDIO MOVIE GRILL
#
#                                  Location Address   Location City  \
# 2448545                           2401 S GREGG ST      BIG SPRING
# 2448546                   245 E COMMERCE ST # 250     SAN ANTONIO
# 2448547                       1201 SAN JACINTO ST         HOUSTON
# 2448548                        2001 N SHEPHERD DR         HOUSTON
# 2448549                 2645 LYNDON B JOHNSON FWY  FARMERS BRANCH
# 2448550                         302 E COMMERCE ST     SAN ANTONIO
# 2448551                      16216 NACOGDOCHES RD     SAN ANTONIO
# 2448552               6421 S BROADWAY AVE STE 130           TYLER
# 2448553                             1802 AVENUE R          SNYDER
# 2448554  805 TOWN AND COUNTRY LN BLDG 10A STE 200         HOUSTON
#
#         Location State  Location Zip  Location County
# 2448545             TX         79720              114
# 2448546             TX         78205               15
# 2448547             TX         77002              101
# 2448548             TX         77008              101
# 2448549             TX         75234               57
# 2448550             TX         78205               15
# 2448551             TX         78247               15
# 2448552             TX         75703              212
# 2448553             TX         79549              208
# 2448554             TX         77024              101

# %%
bars3 = bars2.groupby(['Location Name', 'Location Address','Location State','Location City','Location Zip']).size().reset_index(name='Freq')

# %%
bars3.tail(10000)
# Out:
#                         Location Name               Location Address  \
# 30155   SCOREBOARD SPORTS BAR & GRILL       6507 JESTER BLVD STE 105
# 30156  SCOREBOARDS SPORTS BAR & GRILL           12880 BEAMER RD # IJ
# 30157                          SCORES          1502 N SAINT MARYS ST
# 30158                          SCORES             6340 WESTHEIMER RD
# 30159               SCORES SPORTS BAR              223 W SAN ANTONIO
# ...                               ...                            ...
# 40150         ZYDECO DANCE FUNDRAISER               3006 ROSEDALE ST
# 40151                 ZZ GATOR'S COVE                 733 HAMBLEN RD
# 40152                          ZZIZIM     2625 OLD DENTON RD STE 586
# 40153                      ZZYZX CAFE              3760 S GESSNER RD
# 40154             \FU-DE\ BAR & GRILL  5001 E EXPRESSWAY 83 STE 6506
#
#       Location State  Location City  Location Zip  Freq
# 30155             TX         AUSTIN         78750    64
# 30156             TX        HOUSTON         77089    25
# 30157             TX       BEEVILLE         78102   155
# 30158             TX        HOUSTON         77057   115
# 30159             TX  NEW BRAUNFELS         78130    19
# ...              ...            ...           ...   ...
# 40150             TX        HOUSTON         77004     2
# 40151             TX         HUMBLE         77339   168
# 40152             TX     CARROLLTON         75007    16
# 40153             TX        HOUSTON         77063    27
# 40154             TX       MERCEDES         78570    39
#
# [10000 rows x 6 columns]

# %%
bars3['Google'] = bars3.loc[:,'Location Name'].astype(str).str.cat(bars3.loc[:,'Location Zip'].astype(str), sep=' \"')
bars3['Google'] = bars3.loc[:,'Google'].astype(str).str.cat(bars3.loc[:,'Location Address'].astype(str), sep='\" ')

# %%
#bars3['Google'] = bars3.loc[:,'Location Name'].astype(str).str.cat(bars3.loc[:,'Location Address'].astype(str), sep=' \"')
#bars3['Google'] = bars3.loc[:,'Google'].astype(str).str.cat(bars3.loc[:,'Location Address'].astype(str), sep='\" ')

# %%
bars3.tail(10000)
# Out:
#                         Location Name               Location Address  \
# 30155   SCOREBOARD SPORTS BAR & GRILL       6507 JESTER BLVD STE 105
# 30156  SCOREBOARDS SPORTS BAR & GRILL           12880 BEAMER RD # IJ
# 30157                          SCORES          1502 N SAINT MARYS ST
# 30158                          SCORES             6340 WESTHEIMER RD
# 30159               SCORES SPORTS BAR              223 W SAN ANTONIO
# ...                               ...                            ...
# 40150         ZYDECO DANCE FUNDRAISER               3006 ROSEDALE ST
# 40151                 ZZ GATOR'S COVE                 733 HAMBLEN RD
# 40152                          ZZIZIM     2625 OLD DENTON RD STE 586
# 40153                      ZZYZX CAFE              3760 S GESSNER RD
# 40154             \FU-DE\ BAR & GRILL  5001 E EXPRESSWAY 83 STE 6506
#
#       Location State  Location City  Location Zip  Freq  \
# 30155             TX         AUSTIN         78750    64
# 30156             TX        HOUSTON         77089    25
# 30157             TX       BEEVILLE         78102   155
# 30158             TX        HOUSTON         77057   115
# 30159             TX  NEW BRAUNFELS         78130    19
# ...              ...            ...           ...   ...
# 40150             TX        HOUSTON         77004     2
# 40151             TX         HUMBLE         77339   168
# 40152             TX     CARROLLTON         75007    16
# 40153             TX        HOUSTON         77063    27
# 40154             TX       MERCEDES         78570    39
#
#                                                   Google
# 30155  SCOREBOARD SPORTS BAR & GRILL "78750" 6507 JES...
# 30156  SCOREBOARDS SPORTS BAR & GRILL "77089" 12880 B...
# 30157               SCORES "78102" 1502 N SAINT MARYS ST
# 30158                  SCORES "77057" 6340 WESTHEIMER RD
# 30159        SCORES SPORTS BAR "78130" 223 W SAN ANTONIO
# ...                                                  ...
# 40150   ZYDECO DANCE FUNDRAISER "77004" 3006 ROSEDALE ST
# 40151             ZZ GATOR'S COVE "77339" 733 HAMBLEN RD
# 40152          ZZIZIM "75007" 2625 OLD DENTON RD STE 586
# 40153               ZZYZX CAFE "77063" 3760 S GESSNER RD
# 40154  \FU-DE\ BAR & GRILL "78570" 5001 E EXPRESSWAY ...
#
# [10000 rows x 7 columns]

# %% [markdown]
# # 2. Search each place with Google API

# %%
import json
import re
import requests
import numpy as np
from time import sleep

# %%
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'

# %%
bars3['Google']=bars3['Google'].str.replace('\+','', regex=True)
bars3['Google']=bars3['Google'].str.replace('#','', regex=True)
bars3['Google']=bars3['Google'].str.replace('\&',' ', regex=True)
bars3['Google']=bars3['Google'].str.replace('%',' ', regex=True)
bars3['Google']=bars3['Google'].str.replace('\"','', regex=True)
bars3['Google']=bars3['Google'].str.replace(' ','%20', regex=True)
bars3['Google']=bars3['Google'].str.replace('\'','', regex=True)
bars3['Google']=bars3['Google'].str.replace('\\','', regex=True)
bars3['Google']
# Out:
# 0          3%20SOCIAL%20CLUB%2075650%20704%20W%20MAIN%20ST
# 1        FLAWLESS%20SHOT%20BAR%2078501%20300%20S%2017TH...
# 2        FLAWLESS%20SHOT%20BAR%2078501%209%20S%2011TH%20ST
# 3        101%20POKER%20CLUB%20%20%20RESTAURANT%2077449%...
# 4        76%20BAR%20AND%20KITCHEN%2078504%20400%20W%20N...
#                                ...
# 40150    ZYDECO%20DANCE%20FUNDRAISER%2077004%203006%20R...
# 40151      ZZ%20GATORS%20COVE%2077339%20733%20HAMBLEN%20RD
# 40152    ZZIZIM%2075007%202625%20OLD%20DENTON%20RD%20ST...
# 40153       ZZYZX%20CAFE%2077063%203760%20S%20GESSNER%20RD
# 40154    FU-DE%20BAR%20%20%20GRILL%2078570%205001%20E%2...
# Name: Google, Length: 40155, dtype: object

# %%
search=bars3.iloc[150,6]
search
# Out:
# '2-STEPPIN%20SALOON%2077550%202413%20STRAND%20ST'

# %%
site='https://maps.googleapis.com/maps/api/place/findplacefromtext/json'
inp='?input='+search
inptype='&inputtype=textquery'
fields='&fields=business_status,formatted_address,geometry,name,place_id,price_level,rating,user_ratings_total'
key='&key=AIzaSyBB2fStE8AYv6D4Hk45e4qZs4LZRYTMOtw'
search=site+inp+inptype+fields+key
search
# Out:
# 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=2-STEPPIN%20SALOON%2077550%202413%20STRAND%20ST&inputtype=textquery&fields=business_status,formatted_address,geometry,name,place_id,price_level,rating,user_ratings_total&key=AIzaSyBB2fStE8AYv6D4Hk45e4qZs4LZRYTMOtw'

# %%
req = requests.get(search)

# %%
req.text
# Out:
# '{\n   "candidates" : [\n      {\n         "business_status" : "CLOSED_PERMANENTLY",\n         "formatted_address" : "2413 Strand St, Galveston, TX 77550, United States",\n         "geometry" : {\n            "location" : {\n               "lat" : 29.3064613,\n               "lng" : -94.79600959999999\n            },\n            "viewport" : {\n               "northeast" : {\n                  "lat" : 29.30794287989272,\n                  "lng" : -94.79470592010728\n               },\n               "southwest" : {\n                  "lat" : 29.30524322010728,\n                  "lng" : -94.79740557989273\n               }\n            }\n         },\n         "name" : "2 Steppin Saloon",\n         "place_id" : "ChIJ47QHkmyeP4YRJJLSviGep7w",\n         "rating" : 5,\n         "user_ratings_total" : 2\n      }\n   ],\n   "status" : "OK"\n}\n'

# %%
import json

# %%
data = json.loads(req.text)
data
# Out:
# {'candidates': [{'business_status': 'CLOSED_PERMANENTLY',
#    'formatted_address': '2413 Strand St, Galveston, TX 77550, United States',
#    'geometry': {'location': {'lat': 29.3064613, 'lng': -94.79600959999999},
#     'viewport': {'northeast': {'lat': 29.30794287989272,
#       'lng': -94.79470592010728},
#      'southwest': {'lat': 29.30524322010728, 'lng': -94.79740557989273}}},
#    'name': '2 Steppin Saloon',
#    'place_id': 'ChIJ47QHkmyeP4YRJJLSviGep7w',
#    'rating': 5,
#    'user_ratings_total': 2}],
#  'status': 'OK'}

# %%
frame = pd.json_normalize(data['candidates'])
frame
# Out:
#   business_status                                  formatted_address  \
# 0     OPERATIONAL  2401 Lakeside Pkwy, Flower Mound, TX 75022, Un...
#
#                name                     place_id  rating  user_ratings_total  \
# 0  1845 Taste Texas  ChIJt68xAS0tTIYRFCJz7aGsrAk     4.6                 118
#
#    geometry.location.lat  geometry.location.lng  \
# 0              32.993978              -97.06434
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        32.995229                       -97.063042
#
#    geometry.viewport.southwest.lat  geometry.viewport.southwest.lng
# 0                        32.992529                       -97.065741

# %%
frame2 = pd.json_normalize(data['candidates'])
frame2
# Out:
#       business_status                                  formatted_address  \
# 0  CLOSED_PERMANENTLY  2413 Strand St, Galveston, TX 77550, United St...
#
#                name                     place_id  rating  user_ratings_total  \
# 0  2 Steppin Saloon  ChIJ47QHkmyeP4YRJJLSviGep7w       5                   2
#
#    geometry.location.lat  geometry.location.lng  \
# 0              29.306461              -94.79601
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        29.307943                       -94.794706
#
#    geometry.viewport.southwest.lat  geometry.viewport.southwest.lng
# 0                        29.305243                       -94.797406

# %%
data['status']
# Out:
# 'OK'

# %%
appended_data=[]
appended_data.append(frame)
appended_data.append(frame2)
appended_data = pd.concat(appended_data)
appended_data
appended_data.reset_index()
# Out:
#    index     business_status  \
# 0      0         OPERATIONAL
# 1      0  CLOSED_PERMANENTLY
#
#                                    formatted_address              name  \
# 0  2401 Lakeside Pkwy, Flower Mound, TX 75022, Un...  1845 Taste Texas
# 1  2413 Strand St, Galveston, TX 77550, United St...  2 Steppin Saloon
#
#                       place_id  rating  user_ratings_total  \
# 0  ChIJt68xAS0tTIYRFCJz7aGsrAk     4.6                 118
# 1  ChIJ47QHkmyeP4YRJJLSviGep7w     5.0                   2
#
#    geometry.location.lat  geometry.location.lng  \
# 0              32.993978              -97.06434
# 1              29.306461              -94.79601
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        32.995229                       -97.063042
# 1                        29.307943                       -94.794706
#
#    geometry.viewport.southwest.lat  geometry.viewport.southwest.lng
# 0                        32.992529                       -97.065741
# 1                        29.305243                       -94.797406
#       business_status                                  formatted_address  \
# 0         OPERATIONAL  2401 Lakeside Pkwy, Flower Mound, TX 75022, Un...
# 0  CLOSED_PERMANENTLY  2413 Strand St, Galveston, TX 77550, United St...
#
#                name                     place_id  rating  user_ratings_total  \
# 0  1845 Taste Texas  ChIJt68xAS0tTIYRFCJz7aGsrAk     4.6                 118
# 0  2 Steppin Saloon  ChIJ47QHkmyeP4YRJJLSviGep7w     5.0                   2
#
#    geometry.location.lat  geometry.location.lng  \
# 0              32.993978              -97.06434
# 0              29.306461              -94.79601
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        32.995229                       -97.063042
# 0                        29.307943                       -94.794706
#
#    geometry.viewport.southwest.lat  geometry.viewport.southwest.lng
# 0                        32.992529                       -97.065741
# 0                        29.305243                       -94.797406

# %% [markdown]
# # Search with a loop

# %%
frame = []
original=[]
errs = []
count = 0
count2 = 0
count3 = 0


for i in range(0, 40155): 
    if count==20:
        break
    else:
        search=bars3.iloc[i,6]
        
        city=bars3.iloc[i,3]
        bar_address=bars3.iloc[i,1]
        bar_name=bars3.iloc[i,0]
        bar_zip=bars3.iloc[i,4]


        if city=='AUSTIN':
            count=count+1
            site='https://maps.googleapis.com/maps/api/place/findplacefromtext/json'
            inp='?input='+search
            inptype='&inputtype=textquery'
            fields='&fields=business_status,formatted_address,geometry,name,place_id,price_level,rating,user_ratings_total'
            key='&key=AIzaSyBB2fStE8AYv6D4Hk45e4qZs4LZRYTMOtw'
            search=site+inp+inptype+fields+key
            req = requests.get(search)
            sleep(1.5)
            data = json.loads(req.text)
            if data['status']=='OK':
                count2=count2+1
                if count2==1:
                    frame = pd.json_normalize(data['candidates'])
                    frame['barname']=frame['name']
                    frame['barname']=bar_name
                    frame['baraddr']=frame['name']
                    frame['baraddr']=bar_address
                else:
                    temp = pd.json_normalize(data['candidates'])
                    temp['barname']=temp['name']
                    temp['barname']=bar_name
                    temp['baraddr']=temp['name']
                    temp['baraddr']=bar_address
                    frame=frame.append(temp,ignore_index=True)
                                             
            else:
                count3=count3+1
                if count3==1:
                    temp = search, city, data['status']
                    errs=pd.DataFrame(temp)
                else:
                    temp = search, city, data['status']
                    temp2=pd.DataFrame(temp)
                    errs=errs.append(temp2)

frame
# Out:
#        business_status                                  formatted_address  \
# 0   CLOSED_TEMPORARILY  9601 N Interstate Hwy 35, Austin, TX 78753, Un...
# 1          OPERATIONAL  6929 Airport Blvd #132, Austin, TX 78752, Unit...
# 2   CLOSED_PERMANENTLY  1050 E 11th St # 100, Austin, TX 78702, United...
# 3          OPERATIONAL  1618 E Riverside Dr, Austin, TX 78741, United ...
# 4                  NaN              5509 Colton Rd, Austin, TX 78719, USA
# 5                  NaN             9507 Sherman Rd, Austin, TX 78742, USA
# 6                  NaN           219 W 4th St #219, Austin, TX 78701, USA
# 7   CLOSED_PERMANENTLY      612 W 6th St, Austin, TX 78701, United States
# 8          OPERATIONAL  3003 S Lamar Blvd, Austin, TX 78704, United St...
# 9          OPERATIONAL  600 N Lamar Blvd, Austin, TX 78703, United States
# 10         OPERATIONAL      12013 US-290, Austin, TX 78737, United States
# 11         OPERATIONAL      12013 US-290, Austin, TX 78737, United States
# 12         OPERATIONAL  Austin-Bergstrom International Airport, 3600 P...
# 13         OPERATIONAL  3201 Esperanza Crossing, Austin, TX 78758, Uni...
# 14         OPERATIONAL  8557 Research Blvd #126, Austin, TX 78758, Uni...
# 15  CLOSED_PERMANENTLY  8557 Research Blvd #126, Austin, TX 78758, Uni...
# 16         OPERATIONAL  9828 Great Hills Trail, Austin, TX 78759, Unit...
# 17         OPERATIONAL  3801 N Capital of Texas Hwy G-100, Austin, TX ...
#
#                                    name  \
# 0                             Bout Time
# 1                       101 by Tea Haus
# 2                   11th Street Station
# 3                     1618 Asian Fusion
# 4                        5509 Colton Rd
# 5                       9507 Sherman Rd
# 6                     219 W 4th St #219
# 7                              219 West
# 8                 Baker St. Pub & Grill
# 9                              24 Diner
# 10               290 West Bar and Grill
# 11               290 West Bar and Grill
# 12            Second Bar + Kitchen ABIA
# 13  The Kenzie at the Domain Apartments
# 14                       Ramen Tatsu-ya
# 15                             360 Cafe
# 16                   Great Hills Market
# 17                              360 UNO
#
#                                              place_id  rating  \
# 0                         ChIJMwBOw2_JRIYRs7L8osTchgY     3.0
# 1                         ChIJe9f5BDfKRIYRGvnezyF3buY     4.4
# 2                         ChIJyztwFLu1RIYRFAwKNoooNC0     0.0
# 3                         ChIJS5e6G7a1RIYRxVd0-HJFtRs     4.7
# 4   EiU1NTA5IENvbHRvbiBSZCwgQXVzdGluLCBUWCA3ODcxOS...     NaN
# 5                         ChIJefvkZtu2RIYRaQ4cEb0KaiI     NaN
# 6   EigyMTkgVyA0dGggU3QgIzIxOSwgQXVzdGluLCBUWCA3OD...     NaN
# 7                         ChIJE5p7Jgy1RIYRoN1uGtCUDI0     4.1
# 8                         ChIJx8IlENO0RIYR3OHq9P7i1oQ     4.2
# 9                         ChIJmyMFXBK1RIYRidMZuFx2yLo     4.3
# 10                        ChIJLesA0xtGW4YRHU3i2AXrBUE     4.4
# 11                        ChIJLesA0xtGW4YRHU3i2AXrBUE     4.4
# 12                        ChIJIVOv2C-xRIYRHlJi-KBDoIU     3.4
# 13                        ChIJM6yQunPMRIYRwJd1VOBRdzE     4.1
# 14                        ChIJadj6lsbLRIYRT-N8spPzW7c     4.6
# 15                        ChIJSYFzksbLRIYRDG73tCAEEWM     4.3
# 16                        ChIJlcJf8oPMRIYRFaSDQ6WClbg     4.3
# 17                        ChIJYUkVhCE1W4YRHKLBMDVoMDM     4.5
#
#     user_ratings_total  geometry.location.lat  geometry.location.lng  \
# 0                  5.0              30.360392             -97.685827
# 1                315.0              30.337106             -97.716723
# 2                  0.0              30.269372             -97.729094
# 3                402.0              30.245403             -97.730469
# 4                  NaN              30.175838             -97.688724
# 5                  NaN              30.228494             -97.663923
# 6                  NaN              30.266610             -97.745780
# 7                101.0              30.270069             -97.749014
# 8                693.0              30.242494             -97.783180
# 9               3381.0              30.271964             -97.754260
# 10                86.0              30.210608             -97.968778
# 11                86.0              30.210608             -97.968778
# 12                58.0              30.201965             -97.665725
# 13                44.0              30.398688             -97.723594
# 14              3969.0              30.361154             -97.715150
# 15                 3.0              30.361137             -97.715342
# 16               714.0              30.395489             -97.748980
# 17               317.0              30.336639             -97.803741
#
#     geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                         30.361771                       -97.684561
# 1                         30.338433                       -97.715440
# 2                         30.270792                       -97.727710
# 3                         30.246689                       -97.729240
# 4                         30.177188                       -97.687374
# 5                         30.229896                       -97.662605
# 6                         30.268060                       -97.744391
# 7                         30.271297                       -97.747711
# 8                         30.243889                       -97.781871
# 9                         30.273291                       -97.752738
# 10                        30.211977                       -97.967565
# 11                        30.211977                       -97.967565
# 12                        30.203675                       -97.664454
# 13                        30.400477                       -97.722141
# 14                        30.362481                       -97.713899
# 15                        30.362492                       -97.713971
# 16                        30.396312                       -97.745597
# 17                        30.338018                       -97.802468
#
#     geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                         30.359072                       -97.687261
# 1                         30.335733                       -97.718139
# 2                         30.268092                       -97.730409
# 3                         30.243989                       -97.731940
# 4                         30.174488                       -97.690074
# 5                         30.227196                       -97.665305
# 6                         30.265360                       -97.747091
# 7                         30.268598                       -97.750410
# 8                         30.241189                       -97.784570
# 9                         30.270591                       -97.755437
# 10                        30.209277                       -97.970264
# 11                        30.209277                       -97.970264
# 12                        30.200975                       -97.667153
# 13                        30.397777                       -97.724840
# 14                        30.359781                       -97.716599
# 15                        30.359792                       -97.716671
# 16                        30.393612                       -97.750858
# 17                        30.335319                       -97.805167
#
#                                  barname                             baraddr  \
# 0                             'BOUT TIME                       9601 N I H 35
# 1                        101 BY TEA HAUS           6929 AIRPORT BLVD STE 132
# 2   11TH STREET STATION RESTAURANT & BAR              1050 E 11TH ST STE 100
# 3                      1618 ASIAN FUSION        1620 E RIVERSIDE DR STE 1618
# 4                    183 BUSINESS CENTER                      5509 COLTON RD
# 5                       2015 OYSTER FEST                     9507 SHERMAN RD
# 6                                    219                        219 W 4TH ST
# 7                               219 WEST                        612 W 6TH ST
# 8             221B BAKER ST. PUB & GRILL          3003 S LAMAR BLVD STE F100
# 9                               24 DINER              600 N LAMAR BLVD STE G
# 10                  290 WEST BAR & GRILL          12013 W HIGHWAY 290 UNIT 1
# 11                         290 WEST CLUB          12013 W HIGHWAY 290 UNIT 1
# 12                     2ND BAR & KITCHEN     3600 PRESIDENTIAL BLVD STE 3660
# 13                    3201 AUSTIN LOUNGE                 3201 ESPERANZA XING
# 14                              360 CAFE          8557 RESEARCH BLVD STE 126
# 15                              360 CAFE          8557 RESEARCH BLVD STE 126
# 16                             360 PRIMO        9828 GREAT HILLS TRL STE 120
# 17        360 UNO ESPRESSO & VINO WINERY  3801 CAPITAL OF TX HWY N STE G-100
#
#     price_level
# 0           NaN
# 1           2.0
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           2.0
# 9           2.0
# 10          1.0
# 11          1.0
# 12          2.0
# 13          NaN
# 14          2.0
# 15          NaN
# 16          NaN
# 17          NaN

# %%
errs
# Out:
#                                                    0
# 0  https://maps.googleapis.com/maps/api/place/fin...
# 1                                             AUSTIN
# 2                                       ZERO_RESULTS
# 0  https://maps.googleapis.com/maps/api/place/fin...
# 1                                             AUSTIN
# 2                                       ZERO_RESULTS
# 0  https://maps.googleapis.com/maps/api/place/fin...
# 1                                             AUSTIN
# 2                                       ZERO_RESULTS
